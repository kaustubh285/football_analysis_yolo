# %% [markdown]
# ## Download Dataset from - https://universe.roboflow.com/roboflow-jvuqo/football-players-detection-3zvbc/dataset/1

# %%
# !pip install roboflow

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="22Wi46Sk8yJ0VXSXBevg")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(1)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to football-players-detection-1 in yolov5pytorch:: 100%|██████████| 1338/1338 [00:00<00:00, 2308.33it/s]

# %%
import shutil

shutil.move('football-players-detection-1/train','football-players-detection-1/football-players-detection-1/train')
shutil.move('football-players-detection-1/test','football-players-detection-1/football-players-detection-1/test')
shutil.move('football-players-detection-1/valid','football-players-detection-1/football-players-detection-1/valid')
# Out:
# 'football-players-detection-1/football-players-detection-1/valid'

# %%
import shutil

shutil.move('football-players-detection-1/','/content/drive/MyDrive/football_analysis/football/')
# Out:
# '/content/drive/MyDrive/football_analysis/football/'

# %% [markdown]
# ## Training

# %%
pip install ultralytics

# %%
# !yolo task=detect mode=train model=yolov5n.pt data='/content/football-players-detection-1/data.yaml' epochs=100 imgsz=640
# Out:
# PRO TIP 💡 Replace 'model=yolov5n.pt' with new 'model=yolov5nu.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# ...
# 100% 5.27M/5.27M [00:00<00:00, 74.1MB/s]
# Ultralytics YOLOv8.2.11 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=train model=yolov5x.pt data='/content/drive/MyDrive/football_analysis/football/data.yaml' epochs=100 imgsz=640
# Out:
# PRO TIP 💡 Replace 'model=yolov5x.pt' with new 'model=yolov5xu.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# ...
# 100% 186M/186M [00:00<00:00, 198MB/s]
# Ultralytics YOLOv8.2.11 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !cp /content/runs/detect/train4/weights/best.pt /content/drive/MyDrive/football_analysis/

# %%
# !cp /content/runs/detect/train4/weights/last.pt /content/drive/MyDrive/football_analysis/

# %%
# !cp -r /content/runs/detect/train4/ /content/drive/MyDrive/football_analysis/train/

# %%
# !cp -r /content/runs/detect/train5/ /content/drive/MyDrive/football_analysis/train5/

# %%
# !yolo task=detect mode=train model=yolov5m.pt data='/content/football-players-detection-1/data.yaml' epochs=100 imgsz=640
# Out:
# PRO TIP 💡 Replace 'model=yolov5m.pt' with new 'model=yolov5mu.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# ...
# 100% 48.2M/48.2M [00:00<00:00, 200MB/s]
# Ultralytics YOLOv8.2.11 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
